# %%
import requests
from utils.dbobjects import *
from utils.utils import *
from urllib.request import urlretrieve
import patoolib
from comsear import ComicVineClient
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy.exc import IntegrityError
import pprint
import functools
import json
import shutil
import re
import os
import sys
from pathlib import Path
import datetime
import numpy as np
api_key = 'be9301c9c1770a0c729635a06a4513ad9d95410c'
cv = ComicVineClient(api_key)
root = './data/'
from tqdm.auto import tqdm
from IPython.display import clear_output

# %%
class LibraryParser:
    def __init__(self, library_path):
        self.library_path = Path(library_path)
        self.n_comics = None
        self.n_volumes = None
        
    def scan_root_folder(self):
        folders = list({each.parent for each_ext in ['*.cbr', '*.cbz'] for each in mainp.rglob(each_ext)})
        #subs = {subdir:files for subdir, dirs, files in os.walk(self.library_path) for name in files if name.endswith(('cbr', 'cbz'))}
        for each in folders:
            if 'Issue' in each.name or 'TPB' in each.name:
                to_search.append(each.parent.name)
            else:
                to_search.append(each.name)

# %%
class ComicParser():     
    def __init__(self, path):
        self.comic_name = None
        self.comic_year = None
        self.issue_number = None
        self.comic_path = path
        self.comic_metadata = {}
        self.comic_initiated = False

    def parseComic(self):
        self.comic_name = os.path.splitext(os.path.basename(self.comic_path))[0]
        years = re.findall(r'\(([12]\d{3})', self.comic_name)
        if years:
            year_within_brackets = years[0]
            if (len(year_within_brackets) == 4): #Stupid way of doing but good for now.
                self.comic_year = int(year_within_brackets)
            else:
                self.comic_year = 0
        self.issue_number = re.findall(r"(\d+\.?\d?[a-zA-Z]{0,3}?)(?:\s*\(of|\s*\([12]\d{3}\))", self.comic_path)
        #Get the digits or digits with point number (19.1) or digits followed by letters (19.INH) either before "(of" or before a year.

# %%
class VolumeParser:
    def __init__(self, path):
        self.volume_name = None
        self.type = None #TPB or Single Issues
        self.volume_path = path
        self.volume_initiated = False
        self.volumeDict = {'comics_in_folder' : {} } 
        self.volumeFetch = True
        self.volumeTable = None
        self.searchReturned = None
        self.HEADERS = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:7.0) '
                     'Gecko/20130825 Firefox/36.0'}
        self.params = {'api_key':api_key, 'format': 'json'} 
                
    def parseVolume(self):        
        #There still remains an issue with forward slash in comic path
        if 'Issues' in os.listdir(self.volume_path):
            comic_dir = os.path.join(self.volume_path, 'Issues')            
        else:    
            comic_dir = self.volume_path
        if '(' in self.volume_path:
            self.volume_name = os.path.basename(self.volume_path).split(' (')[0] 
        else:    
            self.volume_name = os.path.basename(self.volume_path) 
            
        self.volumeDict['from_file_volume_name'] = self.volume_name        
        for entry in os.listdir(comic_dir):
            if not entry.startswith(".") and check_comic(entry):
                comic = ComicParser(os.path.join(comic_dir,entry)) #convert to path join volume path and entry
                comic.parseComic()            
                self.volumeDict['comics_in_folder'].update({comic.comic_name : comic})
                                
        print(str(len(self.volumeDict['comics_in_folder']))+' comics added in volume ' + self.volume_name +'.')    
        
    def searchQuery(self,api_key):
        """
        Search Comic Vine Servers
        """
        print("Fetching from Comic Vine servers")
        years = [self.volumeDict['comics_in_folder'][key].comic_year for key in self.volumeDict['comics_in_folder'].keys() if self.volumeDict['comics_in_folder'][key].comic_year]        
        searchtext = self.volumeDict['from_file_volume_name']
        if years:
            searchtext += (' '+str(years[0]))
        print('Querying for '+searchtext)
        firstresponse = cv.search(searchtext, resources=['volume']) #Search for volume name with year
        self.searchReturned = firstresponse.results
        
    def findBestSearch(self):
        """

        Finding best search among Volumes. 2 main information considered 
        here are number of files in folder folder (which is assumed to be 
        total number of issues in that volume) and year range obtained 
        from comic file names.        
        
        """
        print("Finding best match")
        expected_num_comics = len(self.volumeDict['comics_in_folder'])    
        existing_comics = list(self.volumeDict['comics_in_folder'].keys())
        years = [self.volumeDict['comics_in_folder'][key].comic_year for key in self.volumeDict['comics_in_folder'].keys() if self.volumeDict['comics_in_folder'][key].comic_year]
        
        
        flag=False
        best_index = 0
        for indx, each_result in enumerate(self.searchReturned):    
            if indx is 0:
                each_result['match_score'] = 30.0 #First result returned is the best result.
            elif indx is not 0:
                each_result['match_score'] = 0.0
            if expected_num_comics == each_result['count_of_issues']:
                each_result['match_score'] += 10.0 
            if years:    
                if (min(years)<=int(each_result['start_year'])<=max(years)):
                    each_result['match_score'] +=40.0
                    
                    
            ######If scores are still really terrible, then do individual issues check for all issues in search returns.         
            if flag and each_result['match_score']<=40:
                detailresponse = requests.get(each_result['api_detail_url'], headers=self.HEADERS, params=self.params)
                #print(detailresponse.json())
                titles_in_vol = [each['name'] for each in detailresponse.json()['results']['issues']]
                each_result['match_score'] +=fuzz.token_set_ratio(titles_in_vol, exist)
            
            
            
                    
            if each_result['match_score']>=np.array(self.searchReturned)[best_index]['match_score']: #Also assumed that search results are coming back sorted in relavance.
                best_index = indx
        self.volumeDict['best_search']=np.array(self.searchReturned)[best_index]
        print('Match Score : '+ str(self.volumeDict['best_search']['match_score']))        
    
    def confirmResult(self):
        print_com_meta(self.volumeDict['best_search'], 'Best Result:')
        confirmation = query_yes_no("Is the information correct?")
        choice = None
        while True:
            clear_output()
            if not confirmation: 
                for idx, each in enumerate(self.searchReturned):
                    print_com_meta(each, idx+1)
                choice = sanitised_input("Please make a manual choice between 1-10 : ", int, 1,10)
                print_com_meta(self.searchReturned[choice-1], 'Your Choice : ')
                confirmation = query_yes_no("Is the information correct?")
            else:
                if choice:
                    self.volumeDict['best_search'] = self.searchReturned[choice-1]
                break
    
    def fetchVolumeMetadata(self):                                        
        detailresponse = requests.get(self.volumeDict['best_search']['api_detail_url'], headers=self.HEADERS, params=self.params)
        fetched_volume = detailresponse.json()
        self.volumeDict['detailed_meta'] = fetched_volume['results']        
        #Image Directory
        orig_directory = './Resources/Images/VolumeArt/'
        img_name = os.path.basename(self.volumeDict['detailed_meta']['image']['original_url'])
        img_path = os.path.join(orig_directory,img_name)
        #Fetch Image
        urlretrieve(self.volumeDict['detailed_meta']['image']['original_url'], img_path)        
        self.volume_initiated = True
        volume = Volume(
                        id = self.volumeDict['detailed_meta']['id'],
                        name = self.volumeDict['detailed_meta']['name'],
                        aliases = self.volumeDict['detailed_meta']['aliases'],
                        count_of_issues = self.volumeDict['detailed_meta']['count_of_issues'],
                        date_added = self.volumeDict['detailed_meta']['date_added'],
                        date_last_updated = self.volumeDict['detailed_meta']['date_last_updated'],
                        deck = self.volumeDict['detailed_meta']['deck'],
                        description = re.sub(r'<[^>]*>', '', self.volumeDict['detailed_meta']['description']), #remove all within angle brackets
                        publisher = self.volumeDict['detailed_meta']['publisher']['name'], #Later to be changed to publisher object
                        start_year = self.volumeDict['detailed_meta']['start_year'],
                        comicvine_api_detail_url = self.volumeDict['detailed_meta']['api_detail_url'],
                        comicvine_image = self.volumeDict['detailed_meta']['image']['original_url'], #image
                        comicvine_site_detail_url = self.volumeDict['detailed_meta']['site_detail_url'],
                        local_path = self.volume_path,
                        local_image_path = img_path,
                        #character_credits = Column(String)
                        #concept_credits = Column(String)
                        #team_credits = Column(String)
                        #location_credits = Column(String)
                        #object_credits = Column(String)
                        #person_credits = Column(String)
                        )
        self.volumeTable = volume        
        
    def fetchComicsMetadata(self, api_key):
        comic_fetch_loop = tqdm(self.volumeDict['detailed_meta']['issues'])
        comicObjects = []
        issue_directory = './Resources/Images/IssueArt/'                        
        for each_issue in comic_fetch_loop:
            per_issue_response = requests.get(each_issue['api_detail_url'], headers=self.HEADERS, params=self.params).json()['results']
            img_name = os.path.basename(per_issue_response['image']['original_url'])
            img_path = os.path.join(issue_directory,img_name)
            #Fetch Image if doesnt exist
            if not os.path.isfile(img_path):
                urlretrieve(per_issue_response['image']['original_url'], img_path) 
            
            comic = Comic(id = per_issue_response['id'],
                          name = per_issue_response['name'],
                          aliases = per_issue_response['aliases'],
                          deck = per_issue_response['deck'],
                          description = re.sub(r'<[^>]*>', '', per_issue_response['description']),
                          cover_date = per_issue_response['cover_date'],
                          date_added = per_issue_response['date_added'],
                          date_last_updated = per_issue_response['date_last_updated'],
                          issue_number = per_issue_response['issue_number'],
                          comicvine_api_detail_url = per_issue_response['api_detail_url'],
                          comicvine_image = per_issue_response['image']['original_url'],
                          local_image_path = img_path
            )
            comicObjects.append(comic)
            comic_fetch_loop.set_postfix(Status='Added '+str(comic.name))            
        self.volumeTable.comics=set(comicObjects)
     
    def commit_to_db(self, dbpath='sqlite:///comicdb.db'):
        engine = create_engine(dbpath, echo=False)
        Base.metadata.create_all(engine)
        Session = sessionmaker(bind=engine)
        session = Session()
        session.add(self.volumeTable)
        
        try:
            session.commit()
        except IntegrityError:
            session.rollback()
        
        #session.commit()
        session.close()
        engine.dispose()

            
#             for key in self.volumeDict['comics_in_folder'].keys():
#                 if self.volumeDict['comics_in_folder'][key].issue_number == per_issue_response['issue_number'] and self.volumeDict['comics_in_folder'][key].comic_initiated == False:
#                     self.volumeDict['comics_in_folder'][key].comic_metadata = per_issue_response
#                     self.volumeDict['comics_in_folder'][key].comic_initiated = True

# %%
vol1 = VolumeParser('./data/Infinity Gauntlet')
vol1.parseVolume()
vol1.searchQuery(api_key)
vol1.findBestSearch()
vol1.confirmResult()
#vol1.fetchVolumeMetadata()

# %%
vol1.volumeDict['best_search']
# Out:
# {'aliases': None,
#  'api_detail_url': 'https://comicvine.gamespot.com/api/volume/4050-4596/',
#  'count_of_issues': 6,
#  'date_added': '2008-06-06 11:08:19',
#  'date_last_updated': '2019-04-04 02:35:48',
#  'deck': None,
#  'description': '<p>A six issue Limited Series that started the biggest cosmic event in the Marvel Universe! After the events of <a href="/the-thanos-quest/4050-4425/" data-ref-id="4050-4425"> The Thanos Quest</a>, Thanos the Mad Titan has come into possession of the Infinity Gems and wipes out half of the Universe in the blink of an eye for his romantic interest Death. It is up to the remaining heroes of earth and from beyond to stop the mad titan. This series contains the core story of the Infinity Gauntlet crossover event.</p><p>The monthly <a href="/warlock-and-the-infinity-watch/4050-4818/" data-ref-id="4050-4818"> Warlock and the Infinity Watch</a> spun right out of this mini-series.</p><p>This was the first part of the Infinity trilogy. It was continued in <a href="/the-infinity-war/4050-4795/" data-ref-id="4050-4795"> The Infinity War</a> one year later.</p><h4>Collected Editions</h4><ul><li><a href="https://comicvine.gamespot.com/infinity-by-starlin-and-hickman-omnibus/4050-118130/">Infinity by Starlin &amp; Hickman Omnibus</a></li><li><a href="https://comicvine.gamespot.com/infinity-gauntlet-deluxe-edition/4050-116972/" data-ref-id="4050-116972">The Infinity Gauntlet: Deluxe Edition</a></li><li><a href="/infinity-gauntlet-omnibus/4050-75485/" data-ref-id="4050-75485">Infinity Gauntlet Omnibus</a></li><li><a href="https://comicvine.gamespot.com/marvels-avengers-endgame-prelude/4050-118136/">Marvel\'s Avengers: Endgame Prelude</a> (#1)</li></ul>',
#  'first_issue': {'api_detail_url': 'https://comicvine.gamespot.com/api/issue/4000-34415/',
#   'id': 34415,
#   'name': 'God',
#   'issue_number': '1'},
#  'id': 4596,
#  'image': {'icon_url': 'https://comicvine.gamespot.com/api/image/square_avatar/6375308-8894791148-STL078742',
#   'medium_url': 'https://comicvine.gamespot.com/api/image/scale_medium/6375308-8894791148-STL078742',
#   'screen_url': 'https://comicvine.gamespot.com/api/image/screen_medium/6375308-8894791148-STL078742',
#   'screen_large_url': 'https://comicvine.gamespot.com/api/image/screen_kubrick/6375308-8894791148-STL078742',
#   'small_url': 'https://comicvine.gamespot.com/api/image/scale_small/6375308-8894791148-STL078742',
#   'super_url': 'https://comicvine.gamespot.com/api/image/scale_large/6375308-8894791148-STL078742',
#   'thumb_url': 'https://comicvine.gamespot.com/api/image/scale_avatar/6375308-8894791148-STL078742',
#   'tiny_url': 'https://comicvine.gamespot.com/api/image/square_mini/6375308-8894791148-STL078742',
#   'original_url': 'https://comicvine.gamespot.com/api/image/original/6375308-8894791148-STL078742',
#   'image_tags': 'All Images'},
#  'last_issue': {'api_detail_url': 'https://comicvine.gamespot.com/api/issue/4000-35000/',
#   'id': 35000,
#   'name': 'The Final Confrontation',
#   'issue_number': '6'},
#  'name': 'The Infinity Gauntlet',
#  'publisher': {'api_detail_url': 'https://comicvine.gamespot.com/api/publisher/4010-31/',
#   'id': 31,
#   'name': 'Marvel'},
#  'site_detail_url': 'https://comicvine.gamespot.com/the-infinity-gauntlet/4050-4596/',
#  'start_year': '1991',
#  'resource_type': 'volume',
#  'match_score': 50.0}

# %%
vol1.fetchVolumeMetadata()

# %%
vol1.fetchComicsMetadata(api_key)
# Out:
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))

# %%
vol1.commit_to_db()

# %%
subs = {subdir:files for subdir, dirs, files in os.walk('./data') for name in files if name.endswith(('cbr', 'cbz'))}

# %%
list(subs.keys())
#subs['./data/Thor/Thor Vol. 2 (1998-2004)/Issues']
# Out:
# ['./data/Thor/Thor Vol. 2 (1998-2004)/Issues',
#  './data/Hulk/Incredible Hulk 600-611 (2009-2010)/Issues',
#  './data/Infinity Gauntlet/TPB',
#  './data/Infinity Gauntlet/Infinity Gauntlet Aftermath/TPB',
#  './data/Infinity Gauntlet/Issues',
#  './data/Age of Ultron/Issues',
#  './data/Marvel Graphic Novel  (01 - 05)',
#  './data/Venom (Vol. 2)',
#  './data/Inhumans/Inhumans (01-12) (1998-1999)']

# %%
vol1.volumeDict
# Out:
# {'comics_in_folder': {'Infinity Gauntlet 005 (1992) (Digital) (Zone-Empire)': <__main__.ComicParser at 0x11c4965c0>,
#   'Infinity Gauntlet 003 (1991) (Digital) (Zone-Empire)': <__main__.ComicParser at 0x11c496358>,
#   'Infinity Gauntlet 002 (1991) (Digital) (Zone-Empire)': <__main__.ComicParser at 0x11c496320>,
#   'Infinity Gauntlet 004 (1991) (Digital) (Zone-Empire)': <__main__.ComicParser at 0x11c496630>,
#   'Infinity Gauntlet 001 (1991) (Digital) (Zone-Empire)': <__main__.ComicParser at 0x11c4963c8>,
#   'Infinity Gauntlet 006 (1992) (Digital) (Zone-Empire)': <__main__.ComicParser at 0x11c496080>},
#  'from_file_volume_name': 'Infinity Gauntlet',
#  'best_search': {'aliases': None,
#   'api_detail_url': 'https://comicvine.gamespot.com/api/volume/4050-4596/',
#   'count_of_issues': 6,
#   'date_added': '2008-06-06 11:08:19',
#   'date_last_updated': '2019-04-04 02:35:48',
#   'deck': None,
#   'description': '<p>A six issue Limited Series that started the biggest cosmic event in the Marvel Universe! After the events of <a href="/the-thanos-quest/4050-4425/" data-ref-id="4050-4425"> The Thanos Quest</a>, Thanos the Mad Titan has come into possession of the Infinity Gems and wipes out half of the Universe in the blink of an eye for his romantic interest Death. It is up to the remaining heroes of earth and from beyond to stop the mad titan. This series contains the core story of the Infinity Gauntlet crossover event.</p><p>The monthly <a href="/warlock-and-the-infinity-watch/4050-4818/" data-ref-id="4050-4818"> Warlock and the Infinity Watch</a> spun right out of this mini-series.</p><p>This was the first part of the Infinity trilogy. It was continued in <a href="/the-infinity-war/4050-4795/" data-ref-id="4050-4795"> The Infinity War</a> one year later.</p><h4>Collected Editions</h4><ul><li><a href="https://comicvine.gamespot.com/infinity-by-starlin-and-hickman-omnibus/4050-118130/">Infinity by Starlin &amp; Hickman Omnibus</a></li><li><a href="https://comicvine.gamespot.com/infinity-gauntlet-deluxe-edition/4050-116972/" data-ref-id="4050-116972">The Infinity Gauntlet: Deluxe Edition</a></li><li><a href="/infinity-gauntlet-omnibus/4050-75485/" data-ref-id="4050-75485">Infinity Gauntlet Omnibus</a></li><li><a href="https://comicvine.gamespot.com/marvels-avengers-endgame-prelude/4050-118136/">Marvel\'s Avengers: Endgame Prelude</a> (#1)</li></ul>',
#   'first_issue': {'api_detail_url': 'https://comicvine.gamespot.com/api/issue/4000-34415/',
#    'id': 34415,
#    'name': 'God',
#    'issue_number': '1'},
#   'id': 4596,
#   'image': {'icon_url': 'https://comicvine.gamespot.com/api/image/square_avatar/6375308-8894791148-STL078742',
#    'medium_url': 'https://comicvine.gamespot.com/api/image/scale_medium/6375308-8894791148-STL078742',
#    'screen_url': 'https://comicvine.gamespot.com/api/image/screen_medium/6375308-8894791148-STL078742',
#    'screen_large_url': 'https://comicvine.gamespot.com/api/image/screen_kubrick/6375308-8894791148-STL078742',
#    'small_url': 'https://comicvine.gamespot.com/api/image/scale_small/6375308-8894791148-STL078742',
#    'super_url': 'https://comicvine.gamespot.com/api/image/scale_large/6375308-8894791148-STL078742',
#    'thumb_url': 'https://comicvine.gamespot.com/api/image/scale_avatar/6375308-8894791148-STL078742',
#    'tiny_url': 'https://comicvine.gamespot.com/api/image/square_mini/6375308-8894791148-STL078742',
#    'original_url': 'https://comicvine.gamespot.com/api/image/original/6375308-8894791148-STL078742',
#    'image_tags': 'All Images'},
#   'last_issue': {'api_detail_url': 'https://comicvine.gamespot.com/api/issue/4000-35000/',
#    'id': 35000,
#    'name': 'The Final Confrontation',
#    'issue_number': '6'},
#   'name': 'The Infinity Gauntlet',
#   'publisher': {'api_detail_url': 'https://comicvine.gamespot.com/api/publisher/4010-31/',
#    'id': 31,
#    'name': 'Marvel'},
#   'site_detail_url': 'https://comicvine.gamespot.com/the-infinity-gauntlet/4050-4596/',
#   'start_year': '1991',
#   'resource_type': 'volume',
#   'match_score': 50.0},
#  'detailed_meta': {'aliases': None,
#   'api_detail_url': 'https://comicvine.gamespot.com/api/volume/4050-4596/',
#   'characters': [{'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1456/',
#     'id': 1456,
#     'name': 'Doctor Strange',
#     'site_detail_url': 'https://comicvine.gamespot.com/doctor-strange/4005-1456/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2502/',
#     'id': 2502,
#     'name': 'Silver Surfer',
#     'site_detail_url': 'https://comicvine.gamespot.com/silver-surfer/4005-2502/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-6805/',
#     'id': 6805,
#     'name': 'Adam Warlock',
#     'site_detail_url': 'https://comicvine.gamespot.com/adam-warlock/4005-6805/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-6807/',
#     'id': 6807,
#     'name': 'Drax the Destroyer',
#     'site_detail_url': 'https://comicvine.gamespot.com/drax-the-destroyer/4005-6807/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-7108/',
#     'id': 7108,
#     'name': 'Firelord',
#     'site_detail_url': 'https://comicvine.gamespot.com/firelord/4005-7108/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-7257/',
#     'id': 7257,
#     'name': 'Starfox',
#     'site_detail_url': 'https://comicvine.gamespot.com/starfox/4005-7257/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-7607/',
#     'id': 7607,
#     'name': 'Thanos',
#     'site_detail_url': 'https://comicvine.gamespot.com/thanos/4005-7607/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-12620/',
#     'id': 12620,
#     'name': 'Death',
#     'site_detail_url': 'https://comicvine.gamespot.com/death/4005-12620/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-14558/',
#     'id': 14558,
#     'name': 'Nebula',
#     'site_detail_url': 'https://comicvine.gamespot.com/nebula/4005-14558/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1442/',
#     'id': 1442,
#     'name': 'Captain America',
#     'site_detail_url': 'https://comicvine.gamespot.com/captain-america/4005-1442/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1443/',
#     'id': 1443,
#     'name': 'Spider-Man',
#     'site_detail_url': 'https://comicvine.gamespot.com/spider-man/4005-1443/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1455/',
#     'id': 1455,
#     'name': 'Iron Man',
#     'site_detail_url': 'https://comicvine.gamespot.com/iron-man/4005-1455/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1468/',
#     'id': 1468,
#     'name': 'Doctor Doom',
#     'site_detail_url': 'https://comicvine.gamespot.com/doctor-doom/4005-1468/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1504/',
#     'id': 1504,
#     'name': 'Vision',
#     'site_detail_url': 'https://comicvine.gamespot.com/vision/4005-1504/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2149/',
#     'id': 2149,
#     'name': 'Galactus',
#     'site_detail_url': 'https://comicvine.gamespot.com/galactus/4005-2149/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2267/',
#     'id': 2267,
#     'name': 'Hulk',
#     'site_detail_url': 'https://comicvine.gamespot.com/hulk/4005-2267/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2635/',
#     'id': 2635,
#     'name': 'Mephisto',
#     'site_detail_url': 'https://comicvine.gamespot.com/mephisto/4005-2635/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-7611/',
#     'id': 7611,
#     'name': 'Thunderstrike',
#     'site_detail_url': 'https://comicvine.gamespot.com/thunderstrike/4005-7611/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1466/',
#     'id': 1466,
#     'name': 'Scarlet Witch',
#     'site_detail_url': 'https://comicvine.gamespot.com/scarlet-witch/4005-1466/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1474/',
#     'id': 1474,
#     'name': 'Cloak',
#     'site_detail_url': 'https://comicvine.gamespot.com/cloak/4005-1474/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1476/',
#     'id': 1476,
#     'name': 'Namor',
#     'site_detail_url': 'https://comicvine.gamespot.com/namor/4005-1476/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-3319/',
#     'id': 3319,
#     'name': 'Quasar',
#     'site_detail_url': 'https://comicvine.gamespot.com/quasar/4005-3319/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-6143/',
#     'id': 6143,
#     'name': 'Epoch',
#     'site_detail_url': 'https://comicvine.gamespot.com/epoch/4005-6143/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-7120/',
#     'id': 7120,
#     'name': 'Watcher',
#     'site_detail_url': 'https://comicvine.gamespot.com/watcher/4005-7120/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-11332/',
#     'id': 11332,
#     'name': 'Eternity',
#     'site_detail_url': 'https://comicvine.gamespot.com/eternity/4005-11332/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-12903/',
#     'id': 12903,
#     'name': 'Lord Chaos',
#     'site_detail_url': 'https://comicvine.gamespot.com/lord-chaos/4005-12903/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-12904/',
#     'id': 12904,
#     'name': 'Master Order',
#     'site_detail_url': 'https://comicvine.gamespot.com/master-order/4005-12904/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-13332/',
#     'id': 13332,
#     'name': 'Stranger',
#     'site_detail_url': 'https://comicvine.gamespot.com/stranger/4005-13332/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-13782/',
#     'id': 13782,
#     'name': 'Pip the Troll',
#     'site_detail_url': 'https://comicvine.gamespot.com/pip-the-troll/4005-13782/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-14794/',
#     'id': 14794,
#     'name': 'Rintrah',
#     'site_detail_url': 'https://comicvine.gamespot.com/rintrah/4005-14794/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-27672/',
#     'id': 27672,
#     'name': 'Mistress Love',
#     'site_detail_url': 'https://comicvine.gamespot.com/mistress-love/4005-27672/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-27673/',
#     'id': 27673,
#     'name': 'Master Hate',
#     'site_detail_url': 'https://comicvine.gamespot.com/master-hate/4005-27673/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-28005/',
#     'id': 28005,
#     'name': 'Kronos',
#     'site_detail_url': 'https://comicvine.gamespot.com/kronos/4005-28005/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-29861/',
#     'id': 29861,
#     'name': 'One Above All',
#     'site_detail_url': 'https://comicvine.gamespot.com/one-above-all/4005-29861/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-33688/',
#     'id': 33688,
#     'name': 'Ziran the Tester',
#     'site_detail_url': 'https://comicvine.gamespot.com/ziran-the-tester/4005-33688/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1440/',
#     'id': 1440,
#     'name': 'Wolverine',
#     'site_detail_url': 'https://comicvine.gamespot.com/wolverine/4005-1440/',
#     'count': '3'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1449/',
#     'id': 1449,
#     'name': 'She-Hulk',
#     'site_detail_url': 'https://comicvine.gamespot.com/she-hulk/4005-1449/',
#     'count': '3'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1475/',
#     'id': 1475,
#     'name': 'Hawkeye',
#     'site_detail_url': 'https://comicvine.gamespot.com/hawkeye/4005-1475/',
#     'count': '3'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-3202/',
#     'id': 3202,
#     'name': 'Nick Fury',
#     'site_detail_url': 'https://comicvine.gamespot.com/nick-fury/4005-3202/',
#     'count': '3'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-28004/',
#     'id': 28004,
#     'name': 'Terraxia',
#     'site_detail_url': 'https://comicvine.gamespot.com/terraxia/4005-28004/',
#     'count': '3'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1459/',
#     'id': 1459,
#     'name': 'Cyclops',
#     'site_detail_url': 'https://comicvine.gamespot.com/cyclops/4005-1459/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1462/',
#     'id': 1462,
#     'name': 'Beast',
#     'site_detail_url': 'https://comicvine.gamespot.com/beast/4005-1462/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1502/',
#     'id': 1502,
#     'name': 'Wasp',
#     'site_detail_url': 'https://comicvine.gamespot.com/wasp/4005-1502/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1935/',
#     'id': 1935,
#     'name': 'Dagger',
#     'site_detail_url': 'https://comicvine.gamespot.com/dagger/4005-1935/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2105/',
#     'id': 2105,
#     'name': 'Nova',
#     'site_detail_url': 'https://comicvine.gamespot.com/nova/4005-2105/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2118/',
#     'id': 2118,
#     'name': 'Sersi',
#     'site_detail_url': 'https://comicvine.gamespot.com/sersi/4005-2118/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2247/',
#     'id': 2247,
#     'name': 'Hank Pym',
#     'site_detail_url': 'https://comicvine.gamespot.com/hank-pym/4005-2247/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2412/',
#     'id': 2412,
#     'name': 'ALF',
#     'site_detail_url': 'https://comicvine.gamespot.com/alf/4005-2412/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-3200/',
#     'id': 3200,
#     'name': 'Black Widow',
#     'site_detail_url': 'https://comicvine.gamespot.com/black-widow/4005-3200/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-6806/',
#     'id': 6806,
#     'name': 'Gamora',
#     'site_detail_url': 'https://comicvine.gamespot.com/gamora/4005-6806/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-10300/',
#     'id': 10300,
#     'name': 'Beyonder',
#     'site_detail_url': 'https://comicvine.gamespot.com/beyonder/4005-10300/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-14522/',
#     'id': 14522,
#     'name': 'Mentor',
#     'site_detail_url': 'https://comicvine.gamespot.com/mentor/4005-14522/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-22002/',
#     'id': 22002,
#     'name': 'ISAAC',
#     'site_detail_url': 'https://comicvine.gamespot.com/isaac/4005-22002/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-23797/',
#     'id': 23797,
#     'name': 'Valentina de Fontaine',
#     'site_detail_url': 'https://comicvine.gamespot.com/valentina-de-fontaine/4005-23797/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1444/',
#     'id': 1444,
#     'name': 'Storm',
#     'site_detail_url': 'https://comicvine.gamespot.com/storm/4005-1444/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1450/',
#     'id': 1450,
#     'name': 'Luke Cage',
#     'site_detail_url': 'https://comicvine.gamespot.com/luke-cage/4005-1450/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1451/',
#     'id': 1451,
#     'name': 'Falcon',
#     'site_detail_url': 'https://comicvine.gamespot.com/falcon/4005-1451/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1460/',
#     'id': 1460,
#     'name': 'Colossus',
#     'site_detail_url': 'https://comicvine.gamespot.com/colossus/4005-1460/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1461/',
#     'id': 1461,
#     'name': 'Nightcrawler',
#     'site_detail_url': 'https://comicvine.gamespot.com/nightcrawler/4005-1461/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1464/',
#     'id': 1464,
#     'name': 'Iceman',
#     'site_detail_url': 'https://comicvine.gamespot.com/iceman/4005-1464/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1465/',
#     'id': 1465,
#     'name': 'Wonder Man',
#     'site_detail_url': 'https://comicvine.gamespot.com/wonder-man/4005-1465/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1467/',
#     'id': 1467,
#     'name': 'Quicksilver',
#     'site_detail_url': 'https://comicvine.gamespot.com/quicksilver/4005-1467/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1472/',
#     'id': 1472,
#     'name': 'Captain Marvel',
#     'site_detail_url': 'https://comicvine.gamespot.com/captain-marvel/4005-1472/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1477/',
#     'id': 1477,
#     'name': 'Black Panther',
#     'site_detail_url': 'https://comicvine.gamespot.com/black-panther/4005-1477/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1478/',
#     'id': 1478,
#     'name': 'Sasquatch',
#     'site_detail_url': 'https://comicvine.gamespot.com/sasquatch/4005-1478/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1479/',
#     'id': 1479,
#     'name': 'Black Cat',
#     'site_detail_url': 'https://comicvine.gamespot.com/black-cat/4005-1479/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1493/',
#     'id': 1493,
#     'name': 'Moon Knight',
#     'site_detail_url': 'https://comicvine.gamespot.com/moon-knight/4005-1493/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-1525/',
#     'id': 1525,
#     'name': 'Punisher',
#     'site_detail_url': 'https://comicvine.gamespot.com/punisher/4005-1525/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2097/',
#     'id': 2097,
#     'name': 'Rage',
#     'site_detail_url': 'https://comicvine.gamespot.com/rage/4005-2097/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2098/',
#     'id': 2098,
#     'name': 'Night Thrasher',
#     'site_detail_url': 'https://comicvine.gamespot.com/night-thrasher/4005-2098/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2101/',
#     'id': 2101,
#     'name': 'Firestar',
#     'site_detail_url': 'https://comicvine.gamespot.com/firestar/4005-2101/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2112/',
#     'id': 2112,
#     'name': 'Angel',
#     'site_detail_url': 'https://comicvine.gamespot.com/angel/4005-2112/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2113/',
#     'id': 2113,
#     'name': 'Namorita',
#     'site_detail_url': 'https://comicvine.gamespot.com/namorita/4005-2113/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2114/',
#     'id': 2114,
#     'name': 'Thing',
#     'site_detail_url': 'https://comicvine.gamespot.com/thing/4005-2114/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2120/',
#     'id': 2120,
#     'name': 'Human Torch',
#     'site_detail_url': 'https://comicvine.gamespot.com/human-torch/4005-2120/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2151/',
#     'id': 2151,
#     'name': 'Mr. Fantastic',
#     'site_detail_url': 'https://comicvine.gamespot.com/mr-fantastic/4005-2151/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2190/',
#     'id': 2190,
#     'name': 'Invisible Woman',
#     'site_detail_url': 'https://comicvine.gamespot.com/invisible-woman/4005-2190/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2215/',
#     'id': 2215,
#     'name': 'Wong',
#     'site_detail_url': 'https://comicvine.gamespot.com/wong/4005-2215/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2248/',
#     'id': 2248,
#     'name': 'Rick Jones',
#     'site_detail_url': 'https://comicvine.gamespot.com/rick-jones/4005-2248/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2268/',
#     'id': 2268,
#     'name': 'Thor',
#     'site_detail_url': 'https://comicvine.gamespot.com/thor/4005-2268/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2497/',
#     'id': 2497,
#     'name': 'Mockingbird',
#     'site_detail_url': 'https://comicvine.gamespot.com/mockingbird/4005-2497/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-2503/',
#     'id': 2503,
#     'name': 'Hercules',
#     'site_detail_url': 'https://comicvine.gamespot.com/hercules/4005-2503/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-3172/',
#     'id': 3172,
#     'name': 'Black Knight',
#     'site_detail_url': 'https://comicvine.gamespot.com/black-knight/4005-3172/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-3176/',
#     'id': 3176,
#     'name': 'Psylocke',
#     'site_detail_url': 'https://comicvine.gamespot.com/psylocke/4005-3176/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-3190/',
#     'id': 3190,
#     'name': 'Northstar',
#     'site_detail_url': 'https://comicvine.gamespot.com/northstar/4005-3190/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-3324/',
#     'id': 3324,
#     'name': 'Mantis',
#     'site_detail_url': 'https://comicvine.gamespot.com/mantis/4005-3324/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-3489/',
#     'id': 3489,
#     'name': 'Abomination',
#     'site_detail_url': 'https://comicvine.gamespot.com/abomination/4005-3489/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-3507/',
#     'id': 3507,
#     'name': 'Odin',
#     'site_detail_url': 'https://comicvine.gamespot.com/odin/4005-3507/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-3508/',
#     'id': 3508,
#     'name': 'Heimdall',
#     'site_detail_url': 'https://comicvine.gamespot.com/heimdall/4005-3508/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-3511/',
#     'id': 3511,
#     'name': 'Hogun',
#     'site_detail_url': 'https://comicvine.gamespot.com/hogun/4005-3511/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-3512/',
#     'id': 3512,
#     'name': 'Fandral',
#     'site_detail_url': 'https://comicvine.gamespot.com/fandral/4005-3512/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-3513/',
#     'id': 3513,
#     'name': 'Volstagg',
#     'site_detail_url': 'https://comicvine.gamespot.com/volstagg/4005-3513/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-3544/',
#     'id': 3544,
#     'name': 'Sandman',
#     'site_detail_url': 'https://comicvine.gamespot.com/sandman/4005-3544/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-3548/',
#     'id': 3548,
#     'name': 'Kitty Pryde',
#     'site_detail_url': 'https://comicvine.gamespot.com/kitty-pryde/4005-3548/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-3552/',
#     'id': 3552,
#     'name': 'Jean Grey',
#     'site_detail_url': 'https://comicvine.gamespot.com/jean-grey/4005-3552/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-4279/',
#     'id': 4279,
#     'name': 'Forge',
#     'site_detail_url': 'https://comicvine.gamespot.com/forge/4005-4279/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-4315/',
#     'id': 4315,
#     'name': 'Doc Samson',
#     'site_detail_url': 'https://comicvine.gamespot.com/doc-samson/4005-4315/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-4327/',
#     'id': 4327,
#     'name': 'Medusa',
#     'site_detail_url': 'https://comicvine.gamespot.com/medusa/4005-4327/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-4329/',
#     'id': 4329,
#     'name': 'Black Bolt',
#     'site_detail_url': 'https://comicvine.gamespot.com/black-bolt/4005-4329/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-4330/',
#     'id': 4330,
#     'name': 'Gorgon',
#     'site_detail_url': 'https://comicvine.gamespot.com/gorgon/4005-4330/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-4562/',
#     'id': 4562,
#     'name': 'Jubilee',
#     'site_detail_url': 'https://comicvine.gamespot.com/jubilee/4005-4562/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-4811/',
#     'id': 4811,
#     'name': 'Justice',
#     'site_detail_url': 'https://comicvine.gamespot.com/justice/4005-4811/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-5009/',
#     'id': 5009,
#     'name': 'Heather McNeil Hudson',
#     'site_detail_url': 'https://comicvine.gamespot.com/heather-mcneil-hudson/4005-5009/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-5010/',
#     'id': 5010,
#     'name': 'Puck',
#     'site_detail_url': 'https://comicvine.gamespot.com/puck/4005-5010/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-5017/',
#     'id': 5017,
#     'name': 'Shaman',
#     'site_detail_url': 'https://comicvine.gamespot.com/shaman/4005-5017/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-5021/',
#     'id': 5021,
#     'name': 'Diamond Lil',
#     'site_detail_url': 'https://comicvine.gamespot.com/diamond-lil/4005-5021/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-5047/',
#     'id': 5047,
#     'name': 'Guardian',
#     'site_detail_url': 'https://comicvine.gamespot.com/guardian/4005-5047/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-6811/',
#     'id': 6811,
#     'name': 'Living Tribunal',
#     'site_detail_url': 'https://comicvine.gamespot.com/living-tribunal/4005-6811/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-7200/',
#     'id': 7200,
#     'name': 'Sif',
#     'site_detail_url': 'https://comicvine.gamespot.com/sif/4005-7200/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-8474/',
#     'id': 8474,
#     'name': 'Snowbird',
#     'site_detail_url': 'https://comicvine.gamespot.com/snowbird/4005-8474/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-10214/',
#     'id': 10214,
#     'name': 'Texas Twister',
#     'site_detail_url': 'https://comicvine.gamespot.com/texas-twister/4005-10214/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-10226/',
#     'id': 10226,
#     'name': 'Zeus',
#     'site_detail_url': 'https://comicvine.gamespot.com/zeus/4005-10226/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-10964/',
#     'id': 10964,
#     'name': 'Annihilus',
#     'site_detail_url': 'https://comicvine.gamespot.com/annihilus/4005-10964/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-10975/',
#     'id': 10975,
#     'name': 'Karnak',
#     'site_detail_url': 'https://comicvine.gamespot.com/karnak/4005-10975/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-11337/',
#     'id': 11337,
#     'name': 'Spectrum',
#     'site_detail_url': 'https://comicvine.gamespot.com/spectrum/4005-11337/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-11428/',
#     'id': 11428,
#     'name': 'Triton',
#     'site_detail_url': 'https://comicvine.gamespot.com/triton/4005-11428/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-11910/',
#     'id': 11910,
#     'name': 'Alexander Pierce',
#     'site_detail_url': 'https://comicvine.gamespot.com/alexander-pierce/4005-11910/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-12605/',
#     'id': 12605,
#     'name': 'Jim Hammond',
#     'site_detail_url': 'https://comicvine.gamespot.com/jim-hammond/4005-12605/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-13380/',
#     'id': 13380,
#     'name': 'Mary Jane',
#     'site_detail_url': 'https://comicvine.gamespot.com/mary-jane/4005-13380/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-13945/',
#     'id': 13945,
#     'name': 'Makkari',
#     'site_detail_url': 'https://comicvine.gamespot.com/makkari/4005-13945/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-13962/',
#     'id': 13962,
#     'name': 'Osiris',
#     'site_detail_url': 'https://comicvine.gamespot.com/osiris/4005-13962/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-14623/',
#     'id': 14623,
#     'name': 'Kray-Tor',
#     'site_detail_url': 'https://comicvine.gamespot.com/kray-tor/4005-14623/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-14992/',
#     'id': 14992,
#     'name': 'U.S.Agent',
#     'site_detail_url': 'https://comicvine.gamespot.com/usagent/4005-14992/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-21554/',
#     'id': 21554,
#     'name': 'Imei',
#     'site_detail_url': 'https://comicvine.gamespot.com/imei/4005-21554/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-21561/',
#     'id': 21561,
#     'name': 'Carol Danvers',
#     'site_detail_url': 'https://comicvine.gamespot.com/carol-danvers/4005-21561/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-22598/',
#     'id': 22598,
#     'name': 'Windshear',
#     'site_detail_url': 'https://comicvine.gamespot.com/windshear/4005-22598/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-24694/',
#     'id': 24694,
#     'name': 'Daredevil',
#     'site_detail_url': 'https://comicvine.gamespot.com/daredevil/4005-24694/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-31581/',
#     'id': 31581,
#     'name': 'Roger Bochs',
#     'site_detail_url': 'https://comicvine.gamespot.com/roger-bochs/4005-31581/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-33698/',
#     'id': 33698,
#     'name': 'Manitou',
#     'site_detail_url': 'https://comicvine.gamespot.com/manitou/4005-33698/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-41667/',
#     'id': 41667,
#     'name': "S'Byll",
#     'site_detail_url': 'https://comicvine.gamespot.com/sbyll/4005-41667/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-52164/',
#     'id': 52164,
#     'name': 'Captain Autolycus',
#     'site_detail_url': 'https://comicvine.gamespot.com/captain-autolycus/4005-52164/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-58237/',
#     'id': 58237,
#     'name': 'Tezcatlipoca',
#     'site_detail_url': 'https://comicvine.gamespot.com/tezcatlipoca/4005-58237/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-58238/',
#     'id': 58238,
#     'name': 'Itzamna',
#     'site_detail_url': 'https://comicvine.gamespot.com/itzamna/4005-58238/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-58240/',
#     'id': 58240,
#     'name': 'Svarog',
#     'site_detail_url': 'https://comicvine.gamespot.com/svarog/4005-58240/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-58241/',
#     'id': 58241,
#     'name': 'Nuada',
#     'site_detail_url': 'https://comicvine.gamespot.com/nuada/4005-58241/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/character/4005-123126/',
#     'id': 123126,
#     'name': 'Jake Miller',
#     'site_detail_url': 'https://comicvine.gamespot.com/jake-miller/4005-123126/',
#     'count': '1'}],
#   'concepts': [{'api_detail_url': 'https://comicvine.gamespot.com/api/concept/4015-41039/',
#     'id': 41039,
#     'name': 'Power Cosmic',
#     'site_detail_url': 'https://comicvine.gamespot.com/power-cosmic/4015-41039/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/concept/4015-55712/',
#     'id': 55712,
#     'name': 'Time Travel',
#     'site_detail_url': 'https://comicvine.gamespot.com/time-travel/4015-55712/',
#     'count': '3'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/concept/4015-55759/',
#     'id': 55759,
#     'name': 'Magic',
#     'site_detail_url': 'https://comicvine.gamespot.com/magic/4015-55759/',
#     'count': '3'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/concept/4015-56013/',
#     'id': 56013,
#     'name': 'Magical Gateways',
#     'site_detail_url': 'https://comicvine.gamespot.com/magical-gateways/4015-56013/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/concept/4015-56106/',
#     'id': 56106,
#     'name': 'Spider-Sense',
#     'site_detail_url': 'https://comicvine.gamespot.com/spider-sense/4015-56106/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/concept/4015-52203/',
#     'id': 52203,
#     'name': 'Demons',
#     'site_detail_url': 'https://comicvine.gamespot.com/demons/4015-52203/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/concept/4015-56209/',
#     'id': 56209,
#     'name': 'Ghost Rider',
#     'site_detail_url': 'https://comicvine.gamespot.com/ghost-rider/4015-56209/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/concept/4015-56370/',
#     'id': 56370,
#     'name': 'Dimensional Travel',
#     'site_detail_url': 'https://comicvine.gamespot.com/dimensional-travel/4015-56370/',
#     'count': '1'}],
#   'count_of_issues': 6,
#   'date_added': '2008-06-06 11:08:19',
#   'date_last_updated': '2019-04-04 02:35:48',
#   'deck': None,
#   'description': '<p>A six issue Limited Series that started the biggest cosmic event in the Marvel Universe! After the events of <a href="/the-thanos-quest/4050-4425/" data-ref-id="4050-4425"> The Thanos Quest</a>, Thanos the Mad Titan has come into possession of the Infinity Gems and wipes out half of the Universe in the blink of an eye for his romantic interest Death. It is up to the remaining heroes of earth and from beyond to stop the mad titan. This series contains the core story of the Infinity Gauntlet crossover event.</p><p>The monthly <a href="/warlock-and-the-infinity-watch/4050-4818/" data-ref-id="4050-4818"> Warlock and the Infinity Watch</a> spun right out of this mini-series.</p><p>This was the first part of the Infinity trilogy. It was continued in <a href="/the-infinity-war/4050-4795/" data-ref-id="4050-4795"> The Infinity War</a> one year later.</p><h4>Collected Editions</h4><ul><li><a href="https://comicvine.gamespot.com/infinity-by-starlin-and-hickman-omnibus/4050-118130/">Infinity by Starlin &amp; Hickman Omnibus</a></li><li><a href="https://comicvine.gamespot.com/infinity-gauntlet-deluxe-edition/4050-116972/" data-ref-id="4050-116972">The Infinity Gauntlet: Deluxe Edition</a></li><li><a href="/infinity-gauntlet-omnibus/4050-75485/" data-ref-id="4050-75485">Infinity Gauntlet Omnibus</a></li><li><a href="https://comicvine.gamespot.com/marvels-avengers-endgame-prelude/4050-118136/">Marvel\'s Avengers: Endgame Prelude</a> (#1)</li></ul>',
#   'first_issue': {'api_detail_url': 'https://comicvine.gamespot.com/api/issue/4000-34415/',
#    'id': 34415,
#    'name': 'God',
#    'issue_number': '1'},
#   'id': 4596,
#   'image': {'icon_url': 'https://comicvine.gamespot.com/api/image/square_avatar/6375308-8894791148-STL078742',
#    'medium_url': 'https://comicvine.gamespot.com/api/image/scale_medium/6375308-8894791148-STL078742',
#    'screen_url': 'https://comicvine.gamespot.com/api/image/screen_medium/6375308-8894791148-STL078742',
#    'screen_large_url': 'https://comicvine.gamespot.com/api/image/screen_kubrick/6375308-8894791148-STL078742',
#    'small_url': 'https://comicvine.gamespot.com/api/image/scale_small/6375308-8894791148-STL078742',
#    'super_url': 'https://comicvine.gamespot.com/api/image/scale_large/6375308-8894791148-STL078742',
#    'thumb_url': 'https://comicvine.gamespot.com/api/image/scale_avatar/6375308-8894791148-STL078742',
#    'tiny_url': 'https://comicvine.gamespot.com/api/image/square_mini/6375308-8894791148-STL078742',
#    'original_url': 'https://comicvine.gamespot.com/api/image/original/6375308-8894791148-STL078742',
#    'image_tags': 'All Images'},
#   'issues': [{'api_detail_url': 'https://comicvine.gamespot.com/api/issue/4000-34415/',
#     'id': 34415,
#     'name': 'God',
#     'site_detail_url': 'https://comicvine.gamespot.com/the-infinity-gauntlet-1-god/4000-34415/',
#     'issue_number': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/issue/4000-34529/',
#     'id': 34529,
#     'name': 'From Bad to Worse',
#     'site_detail_url': 'https://comicvine.gamespot.com/the-infinity-gauntlet-2-from-bad-to-worse/4000-34529/',
#     'issue_number': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/issue/4000-34647/',
#     'id': 34647,
#     'name': 'Preparations For War',
#     'site_detail_url': 'https://comicvine.gamespot.com/the-infinity-gauntlet-3-preparations-for-war/4000-34647/',
#     'issue_number': '3'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/issue/4000-34764/',
#     'id': 34764,
#     'name': 'Cosmic Battle on the Edge of the Universe',
#     'site_detail_url': 'https://comicvine.gamespot.com/the-infinity-gauntlet-4-cosmic-battle-on-the-edge-/4000-34764/',
#     'issue_number': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/issue/4000-34880/',
#     'id': 34880,
#     'name': 'Astral Conflagration',
#     'site_detail_url': 'https://comicvine.gamespot.com/the-infinity-gauntlet-5-astral-conflagration/4000-34880/',
#     'issue_number': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/issue/4000-35000/',
#     'id': 35000,
#     'name': 'The Final Confrontation',
#     'site_detail_url': 'https://comicvine.gamespot.com/the-infinity-gauntlet-6-the-final-confrontation/4000-35000/',
#     'issue_number': '6'}],
#   'last_issue': {'api_detail_url': 'https://comicvine.gamespot.com/api/issue/4000-35000/',
#    'id': 35000,
#    'name': 'The Final Confrontation',
#    'issue_number': '6'},
#   'locations': [{'api_detail_url': 'https://comicvine.gamespot.com/api/location/4020-56254/',
#     'id': 56254,
#     'name': 'Space',
#     'site_detail_url': 'https://comicvine.gamespot.com/space/4020-56254/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/location/4020-41036/',
#     'id': 41036,
#     'name': 'Avengers Mansion',
#     'site_detail_url': 'https://comicvine.gamespot.com/avengers-mansion/4020-41036/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/location/4020-41183/',
#     'id': 41183,
#     'name': 'New York City',
#     'site_detail_url': 'https://comicvine.gamespot.com/new-york-city/4020-41183/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/location/4020-55966/',
#     'id': 55966,
#     'name': 'Sanctum Sanctorum',
#     'site_detail_url': 'https://comicvine.gamespot.com/sanctum-sanctorum/4020-55966/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/location/4020-41103/',
#     'id': 41103,
#     'name': 'Titan',
#     'site_detail_url': 'https://comicvine.gamespot.com/titan/4020-41103/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/location/4020-56201/',
#     'id': 56201,
#     'name': 'Atlantic Ocean',
#     'site_detail_url': 'https://comicvine.gamespot.com/atlantic-ocean/4020-56201/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/location/4020-56310/',
#     'id': 56310,
#     'name': 'New York State',
#     'site_detail_url': 'https://comicvine.gamespot.com/new-york-state/4020-56310/',
#     'count': '2'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/location/4020-40990/',
#     'id': 40990,
#     'name': 'Asgard',
#     'site_detail_url': 'https://comicvine.gamespot.com/asgard/4020-40990/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/location/4020-42378/',
#     'id': 42378,
#     'name': 'Four Freedoms Plaza',
#     'site_detail_url': 'https://comicvine.gamespot.com/four-freedoms-plaza/4020-42378/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/location/4020-55712/',
#     'id': 55712,
#     'name': 'New Jersey',
#     'site_detail_url': 'https://comicvine.gamespot.com/new-jersey/4020-55712/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/location/4020-57770/',
#     'id': 57770,
#     'name': 'Atlantic City',
#     'site_detail_url': 'https://comicvine.gamespot.com/atlantic-city/4020-57770/',
#     'count': '1'}],
#   'name': 'The Infinity Gauntlet',
#   'objects': [{'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-1456/',
#     'id': 1456,
#     'name': 'Doctor Strange',
#     'site_detail_url': 'https://comicvine.gamespot.com/doctor-strange/4005-1456/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-2502/',
#     'id': 2502,
#     'name': 'Silver Surfer',
#     'site_detail_url': 'https://comicvine.gamespot.com/silver-surfer/4005-2502/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-6805/',
#     'id': 6805,
#     'name': 'Adam Warlock',
#     'site_detail_url': 'https://comicvine.gamespot.com/adam-warlock/4005-6805/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-6807/',
#     'id': 6807,
#     'name': 'Drax the Destroyer',
#     'site_detail_url': 'https://comicvine.gamespot.com/drax-the-destroyer/4005-6807/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-7108/',
#     'id': 7108,
#     'name': 'Firelord',
#     'site_detail_url': 'https://comicvine.gamespot.com/firelord/4005-7108/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-7257/',
#     'id': 7257,
#     'name': 'Starfox',
#     'site_detail_url': 'https://comicvine.gamespot.com/starfox/4005-7257/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-7607/',
#     'id': 7607,
#     'name': 'Thanos',
#     'site_detail_url': 'https://comicvine.gamespot.com/thanos/4005-7607/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-12620/',
#     'id': 12620,
#     'name': 'Death',
#     'site_detail_url': 'https://comicvine.gamespot.com/death/4005-12620/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-14558/',
#     'id': 14558,
#     'name': 'Nebula',
#     'site_detail_url': 'https://comicvine.gamespot.com/nebula/4005-14558/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-1442/',
#     'id': 1442,
#     'name': 'Captain America',
#     'site_detail_url': 'https://comicvine.gamespot.com/captain-america/4005-1442/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-1443/',
#     'id': 1443,
#     'name': 'Spider-Man',
#     'site_detail_url': 'https://comicvine.gamespot.com/spider-man/4005-1443/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-1455/',
#     'id': 1455,
#     'name': 'Iron Man',
#     'site_detail_url': 'https://comicvine.gamespot.com/iron-man/4005-1455/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-1468/',
#     'id': 1468,
#     'name': 'Doctor Doom',
#     'site_detail_url': 'https://comicvine.gamespot.com/doctor-doom/4005-1468/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-1504/',
#     'id': 1504,
#     'name': 'Vision',
#     'site_detail_url': 'https://comicvine.gamespot.com/vision/4005-1504/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-2149/',
#     'id': 2149,
#     'name': 'Galactus',
#     'site_detail_url': 'https://comicvine.gamespot.com/galactus/4005-2149/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-2267/',
#     'id': 2267,
#     'name': 'Hulk',
#     'site_detail_url': 'https://comicvine.gamespot.com/hulk/4005-2267/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-2635/',
#     'id': 2635,
#     'name': 'Mephisto',
#     'site_detail_url': 'https://comicvine.gamespot.com/mephisto/4005-2635/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-7611/',
#     'id': 7611,
#     'name': 'Thunderstrike',
#     'site_detail_url': 'https://comicvine.gamespot.com/thunderstrike/4005-7611/',
#     'count': '5'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-1466/',
#     'id': 1466,
#     'name': 'Scarlet Witch',
#     'site_detail_url': 'https://comicvine.gamespot.com/scarlet-witch/4005-1466/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-1474/',
#     'id': 1474,
#     'name': 'Cloak',
#     'site_detail_url': 'https://comicvine.gamespot.com/cloak/4005-1474/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-1476/',
#     'id': 1476,
#     'name': 'Namor',
#     'site_detail_url': 'https://comicvine.gamespot.com/namor/4005-1476/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-3319/',
#     'id': 3319,
#     'name': 'Quasar',
#     'site_detail_url': 'https://comicvine.gamespot.com/quasar/4005-3319/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-6143/',
#     'id': 6143,
#     'name': 'Epoch',
#     'site_detail_url': 'https://comicvine.gamespot.com/epoch/4005-6143/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-7120/',
#     'id': 7120,
#     'name': 'Watcher',
# ...
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-2190/',
#     'id': 2190,
#     'name': 'Invisible Woman',
#     'site_detail_url': 'https://comicvine.gamespot.com/invisible-woman/4005-2190/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-2215/',
#     'id': 2215,
#     'name': 'Wong',
#     'site_detail_url': 'https://comicvine.gamespot.com/wong/4005-2215/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-2248/',
#     'id': 2248,
#     'name': 'Rick Jones',
#     'site_detail_url': 'https://comicvine.gamespot.com/rick-jones/4005-2248/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-2268/',
#     'id': 2268,
#     'name': 'Thor',
#     'site_detail_url': 'https://comicvine.gamespot.com/thor/4005-2268/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-2497/',
#     'id': 2497,
#     'name': 'Mockingbird',
#     'site_detail_url': 'https://comicvine.gamespot.com/mockingbird/4005-2497/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-2503/',
#     'id': 2503,
#     'name': 'Hercules',
#     'site_detail_url': 'https://comicvine.gamespot.com/hercules/4005-2503/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-3172/',
#     'id': 3172,
#     'name': 'Black Knight',
#     'site_detail_url': 'https://comicvine.gamespot.com/black-knight/4005-3172/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-3176/',
#     'id': 3176,
#     'name': 'Psylocke',
#     'site_detail_url': 'https://comicvine.gamespot.com/psylocke/4005-3176/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-3190/',
#     'id': 3190,
#     'name': 'Northstar',
#     'site_detail_url': 'https://comicvine.gamespot.com/northstar/4005-3190/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-3324/',
#     'id': 3324,
#     'name': 'Mantis',
#     'site_detail_url': 'https://comicvine.gamespot.com/mantis/4005-3324/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-3489/',
#     'id': 3489,
#     'name': 'Abomination',
#     'site_detail_url': 'https://comicvine.gamespot.com/abomination/4005-3489/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-3507/',
#     'id': 3507,
#     'name': 'Odin',
#     'site_detail_url': 'https://comicvine.gamespot.com/odin/4005-3507/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-3508/',
#     'id': 3508,
#     'name': 'Heimdall',
#     'site_detail_url': 'https://comicvine.gamespot.com/heimdall/4005-3508/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-3511/',
#     'id': 3511,
#     'name': 'Hogun',
#     'site_detail_url': 'https://comicvine.gamespot.com/hogun/4005-3511/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-3512/',
#     'id': 3512,
#     'name': 'Fandral',
#     'site_detail_url': 'https://comicvine.gamespot.com/fandral/4005-3512/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-3513/',
#     'id': 3513,
#     'name': 'Volstagg',
#     'site_detail_url': 'https://comicvine.gamespot.com/volstagg/4005-3513/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-3544/',
#     'id': 3544,
#     'name': 'Sandman',
#     'site_detail_url': 'https://comicvine.gamespot.com/sandman/4005-3544/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-3548/',
#     'id': 3548,
#     'name': 'Kitty Pryde',
#     'site_detail_url': 'https://comicvine.gamespot.com/kitty-pryde/4005-3548/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-3552/',
#     'id': 3552,
#     'name': 'Jean Grey',
#     'site_detail_url': 'https://comicvine.gamespot.com/jean-grey/4005-3552/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-4279/',
#     'id': 4279,
#     'name': 'Forge',
#     'site_detail_url': 'https://comicvine.gamespot.com/forge/4005-4279/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-4315/',
#     'id': 4315,
#     'name': 'Doc Samson',
#     'site_detail_url': 'https://comicvine.gamespot.com/doc-samson/4005-4315/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-4327/',
#     'id': 4327,
#     'name': 'Medusa',
#     'site_detail_url': 'https://comicvine.gamespot.com/medusa/4005-4327/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-4329/',
#     'id': 4329,
#     'name': 'Black Bolt',
#     'site_detail_url': 'https://comicvine.gamespot.com/black-bolt/4005-4329/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-4330/',
#     'id': 4330,
#     'name': 'Gorgon',
#     'site_detail_url': 'https://comicvine.gamespot.com/gorgon/4005-4330/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-4562/',
#     'id': 4562,
#     'name': 'Jubilee',
#     'site_detail_url': 'https://comicvine.gamespot.com/jubilee/4005-4562/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-4811/',
#     'id': 4811,
#     'name': 'Justice',
#     'site_detail_url': 'https://comicvine.gamespot.com/justice/4005-4811/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-5009/',
#     'id': 5009,
#     'name': 'Heather McNeil Hudson',
#     'site_detail_url': 'https://comicvine.gamespot.com/heather-mcneil-hudson/4005-5009/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-5010/',
#     'id': 5010,
#     'name': 'Puck',
#     'site_detail_url': 'https://comicvine.gamespot.com/puck/4005-5010/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-5017/',
#     'id': 5017,
#     'name': 'Shaman',
#     'site_detail_url': 'https://comicvine.gamespot.com/shaman/4005-5017/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-5021/',
#     'id': 5021,
#     'name': 'Diamond Lil',
#     'site_detail_url': 'https://comicvine.gamespot.com/diamond-lil/4005-5021/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-5047/',
#     'id': 5047,
#     'name': 'Guardian',
#     'site_detail_url': 'https://comicvine.gamespot.com/guardian/4005-5047/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-6811/',
#     'id': 6811,
#     'name': 'Living Tribunal',
#     'site_detail_url': 'https://comicvine.gamespot.com/living-tribunal/4005-6811/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-7200/',
#     'id': 7200,
#     'name': 'Sif',
#     'site_detail_url': 'https://comicvine.gamespot.com/sif/4005-7200/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-8474/',
#     'id': 8474,
#     'name': 'Snowbird',
#     'site_detail_url': 'https://comicvine.gamespot.com/snowbird/4005-8474/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-10214/',
#     'id': 10214,
#     'name': 'Texas Twister',
#     'site_detail_url': 'https://comicvine.gamespot.com/texas-twister/4005-10214/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-10226/',
#     'id': 10226,
#     'name': 'Zeus',
#     'site_detail_url': 'https://comicvine.gamespot.com/zeus/4005-10226/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-10964/',
#     'id': 10964,
#     'name': 'Annihilus',
#     'site_detail_url': 'https://comicvine.gamespot.com/annihilus/4005-10964/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-10975/',
#     'id': 10975,
#     'name': 'Karnak',
#     'site_detail_url': 'https://comicvine.gamespot.com/karnak/4005-10975/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-11337/',
#     'id': 11337,
#     'name': 'Spectrum',
#     'site_detail_url': 'https://comicvine.gamespot.com/spectrum/4005-11337/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-11428/',
#     'id': 11428,
#     'name': 'Triton',
#     'site_detail_url': 'https://comicvine.gamespot.com/triton/4005-11428/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-11910/',
#     'id': 11910,
#     'name': 'Alexander Pierce',
#     'site_detail_url': 'https://comicvine.gamespot.com/alexander-pierce/4005-11910/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-12605/',
#     'id': 12605,
#     'name': 'Jim Hammond',
#     'site_detail_url': 'https://comicvine.gamespot.com/jim-hammond/4005-12605/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-13380/',
#     'id': 13380,
#     'name': 'Mary Jane',
#     'site_detail_url': 'https://comicvine.gamespot.com/mary-jane/4005-13380/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-13945/',
#     'id': 13945,
#     'name': 'Makkari',
#     'site_detail_url': 'https://comicvine.gamespot.com/makkari/4005-13945/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-13962/',
#     'id': 13962,
#     'name': 'Osiris',
#     'site_detail_url': 'https://comicvine.gamespot.com/osiris/4005-13962/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-14623/',
#     'id': 14623,
#     'name': 'Kray-Tor',
#     'site_detail_url': 'https://comicvine.gamespot.com/kray-tor/4005-14623/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-14992/',
#     'id': 14992,
#     'name': 'U.S.Agent',
#     'site_detail_url': 'https://comicvine.gamespot.com/usagent/4005-14992/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-21554/',
#     'id': 21554,
#     'name': 'Imei',
#     'site_detail_url': 'https://comicvine.gamespot.com/imei/4005-21554/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-21561/',
#     'id': 21561,
#     'name': 'Carol Danvers',
#     'site_detail_url': 'https://comicvine.gamespot.com/carol-danvers/4005-21561/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-22598/',
#     'id': 22598,
#     'name': 'Windshear',
#     'site_detail_url': 'https://comicvine.gamespot.com/windshear/4005-22598/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-24694/',
#     'id': 24694,
#     'name': 'Daredevil',
#     'site_detail_url': 'https://comicvine.gamespot.com/daredevil/4005-24694/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-31581/',
#     'id': 31581,
#     'name': 'Roger Bochs',
#     'site_detail_url': 'https://comicvine.gamespot.com/roger-bochs/4005-31581/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-33698/',
#     'id': 33698,
#     'name': 'Manitou',
#     'site_detail_url': 'https://comicvine.gamespot.com/manitou/4005-33698/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-41667/',
#     'id': 41667,
#     'name': "S'Byll",
#     'site_detail_url': 'https://comicvine.gamespot.com/sbyll/4005-41667/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-52164/',
#     'id': 52164,
#     'name': 'Captain Autolycus',
#     'site_detail_url': 'https://comicvine.gamespot.com/captain-autolycus/4005-52164/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-58237/',
#     'id': 58237,
#     'name': 'Tezcatlipoca',
#     'site_detail_url': 'https://comicvine.gamespot.com/tezcatlipoca/4005-58237/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-58238/',
#     'id': 58238,
#     'name': 'Itzamna',
#     'site_detail_url': 'https://comicvine.gamespot.com/itzamna/4005-58238/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-58240/',
#     'id': 58240,
#     'name': 'Svarog',
#     'site_detail_url': 'https://comicvine.gamespot.com/svarog/4005-58240/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-58241/',
#     'id': 58241,
#     'name': 'Nuada',
#     'site_detail_url': 'https://comicvine.gamespot.com/nuada/4005-58241/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/object/4005-123126/',
#     'id': 123126,
#     'name': 'Jake Miller',
#     'site_detail_url': 'https://comicvine.gamespot.com/jake-miller/4005-123126/',
#     'count': '1'}],
#   'people': [{'api_detail_url': 'https://comicvine.gamespot.com/api/person/4040-1669/',
#     'id': 1669,
#     'name': 'Joe Rubinstein',
#     'site_detail_url': 'https://comicvine.gamespot.com/joe-rubinstein/4040-1669/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/person/4040-2913/',
#     'id': 2913,
#     'name': 'George Pérez',
#     'site_detail_url': 'https://comicvine.gamespot.com/george-perez/4040-2913/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/person/4040-7922/',
#     'id': 7922,
#     'name': 'Jim Starlin',
#     'site_detail_url': 'https://comicvine.gamespot.com/jim-starlin/4040-7922/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/person/4040-21199/',
#     'id': 21199,
#     'name': 'Jack Morelli',
#     'site_detail_url': 'https://comicvine.gamespot.com/jack-morelli/4040-21199/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/person/4040-40451/',
#     'id': 40451,
#     'name': 'Christie Scheele',
#     'site_detail_url': 'https://comicvine.gamespot.com/christie-scheele/4040-40451/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/person/4040-41037/',
#     'id': 41037,
#     'name': 'Tom DeFalco',
#     'site_detail_url': 'https://comicvine.gamespot.com/tom-defalco/4040-41037/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/person/4040-42549/',
#     'id': 42549,
#     'name': 'Craig Anderson',
#     'site_detail_url': 'https://comicvine.gamespot.com/craig-anderson/4040-42549/',
#     'count': '6'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/person/4040-20719/',
#     'id': 20719,
#     'name': 'Ian Laughlin',
#     'site_detail_url': 'https://comicvine.gamespot.com/ian-laughlin/4040-20719/',
#     'count': '4'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/person/4040-3258/',
#     'id': 3258,
#     'name': 'Ron Lim',
#     'site_detail_url': 'https://comicvine.gamespot.com/ron-lim/4040-3258/',
#     'count': '3'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/person/4040-13740/',
#     'id': 13740,
#     'name': 'Tom Christopher',
#     'site_detail_url': 'https://comicvine.gamespot.com/tom-christopher/4040-13740/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/person/4040-25677/',
#     'id': 25677,
#     'name': 'Evelyn Stein',
#     'site_detail_url': 'https://comicvine.gamespot.com/evelyn-stein/4040-25677/',
#     'count': '1'},
#    {'api_detail_url': 'https://comicvine.gamespot.com/api/person/4040-42550/',
#     'id': 42550,
#     'name': 'John Lewandowski',
#     'site_detail_url': 'https://comicvine.gamespot.com/john-lewandowski/4040-42550/',
#     'count': '1'}],
#   'publisher': {'api_detail_url': 'https://comicvine.gamespot.com/api/publisher/4010-31/',
#    'id': 31,
#    'name': 'Marvel'},
#   'site_detail_url': 'https://comicvine.gamespot.com/the-infinity-gauntlet/4050-4596/',
#   'start_year': '1991'}}

# %%
mainp = Path('./data')

# %%
folders = list({each.parent for each_ext in ['*.cbr', '*.cbz'] for each in mainp.rglob(each_ext)})
folders
# Out:
# [PosixPath('data/Age of Ultron/Issues'),
#  PosixPath('data/Hulk/Incredible Hulk 600-611 (2009-2010)/Issues'),
#  PosixPath('data/Infinity Gauntlet/Infinity Gauntlet Aftermath/TPB'),
#  PosixPath('data/Inhumans/Inhumans (01-12) (1998-1999)'),
#  PosixPath('data/Thor/Thor Vol. 2 (1998-2004)/Issues'),
#  PosixPath('data/Venom (Vol. 2)'),
#  PosixPath('data/Infinity Gauntlet/TPB'),
#  PosixPath('data/Marvel Graphic Novel  (01 - 05)'),
#  PosixPath('data/Infinity Gauntlet/Issues')]

# %%
list(folders[0].glob('*'))[0].name
# Out:
# 'Age of Ultron 009 (2013) (Digital) (Zone-Empire).cbr'

# %%
to_search = []
for each in folders:
    if 'Issue' in each.name or 'TPB' in each.name:
        to_search.append(each.parent.name)
    else:
        to_search.append(each.name)
to_search
# Out:
# ['Age of Ultron',
#  'Incredible Hulk 600-611 (2009-2010)',
#  'Infinity Gauntlet Aftermath',
#  'Inhumans (01-12) (1998-1999)',
#  'Thor Vol. 2 (1998-2004)',
#  'Venom (Vol. 2)',
#  'Infinity Gauntlet',
#  'Marvel Graphic Novel  (01 - 05)',
#  'Infinity Gauntlet']
